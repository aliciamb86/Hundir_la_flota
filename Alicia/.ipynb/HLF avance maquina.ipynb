# %%
import numpy as np
import random
import time

# %%
def crear_tablero(tamaño=(10,10)):
    tablero = np.full(tamaño, "·")
    return tablero

# %%
# def crear_tablero(base=10,altura=10):
#     tablero = np.full((base + 1, altura + 1), "·")
#     tablero[0,:] = np.array(range(altura + 1))
#     tablero[:,0] = np.array(range(base + 1))
#     tablero[0,0] = '*'
#     return tablero

# %%
tablero = crear_tablero()
print(tablero)
# Out:
# [['·' '·' '·' '·' '·' '·' '·' '·' '·' '·']
#  ['·' '·' '·' '·' '·' '·' '·' '·' '·' '·']
#  ['·' '·' '·' '·' '·' '·' '·' '·' '·' '·']
#  ['·' '·' '·' '·' '·' '·' '·' '·' '·' '·']
#  ['·' '·' '·' '·' '·' '·' '·' '·' '·' '·']
#  ['·' '·' '·' '·' '·' '·' '·' '·' '·' '·']
#  ['·' '·' '·' '·' '·' '·' '·' '·' '·' '·']
#  ['·' '·' '·' '·' '·' '·' '·' '·' '·' '·']
#  ['·' '·' '·' '·' '·' '·' '·' '·' '·' '·']
#  ['·' '·' '·' '·' '·' '·' '·' '·' '·' '·']]

# %%
contador = 0

# %%
def colocar_barco(barco, tablero):
    for casilla in barco:
        tablero[casilla] = "O"
    return tablero

# %%
def crear_barco(eslora, tablero_maq, contador):    
    # elegimos aleatoriamente el punto de partida desde el que se colocará nuestro barco
    fila_a = random.randint(0,9)
    columna_a = random.randint(0,9)

    # declaramos como primera posición de nuestro barco los valores obtenidos aleatoriamente
    # declaramos nuestro barco, con la ubicación del punto de partida
    fila_inicio = fila_a
    columna_inicio = columna_a
    barco = [(fila_inicio, columna_inicio)]
    print(fila_a,columna_a)

    # elegimos aleatoriamente la dirección en la que se posicionará nuestro barco
    orientacion = random.choice(["S","O","E","N"])
    print(orientacion)
    while len(barco) < eslora:
        match orientacion:
            case "O":
                if columna_a - (eslora - 1) >= 0:
                    columna_inicio -= 1 
                else:
                    orientacion = random.choice(["S","E","N"])
                    print(orientacion)
                    continue
            case "E":
                if columna_a + (eslora - 1) <= 9:
                    columna_inicio += 1
                else:
                    orientacion = random.choice(["S","O","N"])
                    print(orientacion)
                    continue
            case "S":
                if fila_a + (eslora - 1) <= 9:
                    fila_inicio += 1
                else:
                    orientacion = random.choice(["O","E","N"])
                    print(orientacion)
                    continue
            case "N":
                if fila_a - (eslora - 1) >= 0:
                    fila_inicio -= 1
                else:
                    orientacion = random.choice(["S","O","E"])
                    print(orientacion)
                    continue
        barco.append((fila_inicio, columna_inicio))
    else:
        for casilla in barco:
            if tablero_maq[casilla] != "O":
                contador +=1
                if contador == eslora:
                    # barcos.append(barco)
                    tablero_maq = colocar_barco(barco, tablero_maq)
                    print('Barco de ', len(barco), 'de eslora colocado en posicion ', barco, 'orientación', orientacion)
                    print(barco)
                    print(tablero_maq)
                    break
            else:
                # print('Creando nuevo barco')
                crear_barco(eslora, tablero_maq, contador)
                break

# %% [markdown]
#     * 4 barcos de 1 posición de eslora
#     * 3 barcos de 2 posiciones de eslora
#     * 2 barcos de 3 posiciones de eslora
#     * 1 barco de 4 posiciones de eslora

# %%
tablero_maq = crear_tablero()

# %%
barco_1_1 = crear_barco(1, tablero_maq, contador)
barco_2_1 = crear_barco(1, tablero_maq, contador)
barco_3_1 = crear_barco(1, tablero_maq, contador)
barco_4_1 = crear_barco(1, tablero_maq, contador)
barco_5_1 = crear_barco(2, tablero_maq, contador)
barco_6_1 = crear_barco(2, tablero_maq, contador)
barco_7_1 = crear_barco(2, tablero_maq, contador)
barco_8_1 = crear_barco(3, tablero_maq, contador)
barco_9_1 = crear_barco(3, tablero_maq, contador)
barco_10_1 = crear_barco(4, tablero_maq, contador)
print(tablero_maq)
# Out:
# 9 5
# E
# Barco de  1 de eslora colocado en posicion  [(9, 5)] orientación E
# [(9, 5)]
# [['·' '·' '·' '·' '·' '·' '·' '·' '·' '·']
#  ['·' '·' '·' '·' '·' '·' '·' '·' '·' '·']
#  ['·' '·' '·' '·' '·' '·' '·' '·' '·' '·']
#  ['·' '·' '·' '·' '·' '·' '·' '·' '·' '·']
#  ['·' '·' '·' '·' '·' '·' '·' '·' '·' '·']
#  ['·' '·' '·' '·' '·' '·' '·' '·' '·' '·']
#  ['·' '·' '·' '·' '·' '·' '·' '·' '·' '·']
#  ['·' '·' '·' '·' '·' '·' '·' '·' '·' '·']
#  ['·' '·' '·' '·' '·' '·' '·' '·' '·' '·']
#  ['·' '·' '·' '·' '·' 'O' '·' '·' '·' '·']]
# 5 7
# E
# Barco de  1 de eslora colocado en posicion  [(5, 7)] orientación E
# [(5, 7)]
# [['·' '·' '·' '·' '·' '·' '·' '·' '·' '·']
#  ['·' '·' '·' '·' '·' '·' '·' '·' '·' '·']
#  ['·' '·' '·' '·' '·' '·' '·' '·' '·' '·']
#  ['·' '·' '·' '·' '·' '·' '·' '·' '·' '·']
#  ['·' '·' '·' '·' '·' '·' '·' '·' '·' '·']
#  ['·' '·' '·' '·' '·' '·' '·' 'O' '·' '·']
#  ['·' '·' '·' '·' '·' '·' '·' '·' '·' '·']
#  ['·' '·' '·' '·' '·' '·' '·' '·' '·' '·']
#  ['·' '·' '·' '·' '·' '·' '·' '·' '·' '·']
#  ['·' '·' '·' '·' '·' 'O' '·' '·' '·' '·']]
# 5 7
# S
# 9 9
# N
# Barco de  1 de eslora colocado en posicion  [(9, 9)] orientación N
# [(9, 9)]
# [['·' '·' '·' '·' '·' '·' '·' '·' '·' '·']
#  ['·' '·' '·' '·' '·' '·' '·' '·' '·' '·']
#  ['·' '·' '·' '·' '·' '·' '·' '·' '·' '·']
#  ['·' '·' '·' '·' '·' '·' '·' '·' '·' '·']
#  ['·' '·' '·' '·' '·' '·' '·' '·' '·' '·']
#  ['·' '·' '·' '·' '·' '·' '·' 'O' '·' '·']
#  ['·' '·' '·' '·' '·' '·' '·' '·' '·' '·']
#  ['·' '·' '·' '·' '·' '·' '·' '·' '·' '·']
#  ['·' '·' '·' '·' '·' '·' '·' '·' '·' '·']
#  ['·' '·' '·' '·' '·' 'O' '·' '·' '·' 'O']]
# 4 2
# N
# Barco de  1 de eslora colocado en posicion  [(4, 2)] orientación N
# [(4, 2)]
# [['·' '·' '·' '·' '·' '·' '·' '·' '·' '·']
#  ['·' '·' '·' '·' '·' '·' '·' '·' '·' '·']
#  ['·' '·' '·' '·' '·' '·' '·' '·' '·' '·']
#  ['·' '·' '·' '·' '·' '·' '·' '·' '·' '·']
#  ['·' '·' 'O' '·' '·' '·' '·' '·' '·' '·']
#  ['·' '·' '·' '·' '·' '·' '·' 'O' '·' '·']
#  ['·' '·' '·' '·' '·' '·' '·' '·' '·' '·']
#  ['·' '·' '·' '·' '·' '·' '·' '·' '·' '·']
#  ['·' '·' '·' '·' '·' '·' '·' '·' '·' '·']
#  ['·' '·' '·' '·' '·' 'O' '·' '·' '·' 'O']]
# 5 6
# N
# Barco de  2 de eslora colocado en posicion  [(5, 6), (4, 6)] orientación N
# [(5, 6), (4, 6)]
# [['·' '·' '·' '·' '·' '·' '·' '·' '·' '·']
#  ['·' '·' '·' '·' '·' '·' '·' '·' '·' '·']
#  ['·' '·' '·' '·' '·' '·' '·' '·' '·' '·']
#  ['·' '·' '·' '·' '·' '·' '·' '·' '·' '·']
#  ['·' '·' 'O' '·' '·' '·' 'O' '·' '·' '·']
#  ['·' '·' '·' '·' '·' '·' 'O' 'O' '·' '·']
#  ['·' '·' '·' '·' '·' '·' '·' '·' '·' '·']
#  ['·' '·' '·' '·' '·' '·' '·' '·' '·' '·']
#  ['·' '·' '·' '·' '·' '·' '·' '·' '·' '·']
#  ['·' '·' '·' '·' '·' 'O' '·' '·' '·' 'O']]
# 1 1
# O
# Barco de  2 de eslora colocado en posicion  [(1, 1), (1, 0)] orientación O
# [(1, 1), (1, 0)]
# [['·' '·' '·' '·' '·' '·' '·' '·' '·' '·']
#  ['O' 'O' '·' '·' '·' '·' '·' '·' '·' '·']
#  ['·' '·' '·' '·' '·' '·' '·' '·' '·' '·']
#  ['·' '·' '·' '·' '·' '·' '·' '·' '·' '·']
#  ['·' '·' 'O' '·' '·' '·' 'O' '·' '·' '·']
#  ['·' '·' '·' '·' '·' '·' 'O' 'O' '·' '·']
#  ['·' '·' '·' '·' '·' '·' '·' '·' '·' '·']
#  ['·' '·' '·' '·' '·' '·' '·' '·' '·' '·']
#  ['·' '·' '·' '·' '·' '·' '·' '·' '·' '·']
#  ['·' '·' '·' '·' '·' 'O' '·' '·' '·' 'O']]
# 1 1
# N
# 8 8
# O
# Barco de  2 de eslora colocado en posicion  [(8, 8), (8, 7)] orientación O
# [(8, 8), (8, 7)]
# [['·' '·' '·' '·' '·' '·' '·' '·' '·' '·']
#  ['O' 'O' '·' '·' '·' '·' '·' '·' '·' '·']
#  ['·' '·' '·' '·' '·' '·' '·' '·' '·' '·']
#  ['·' '·' '·' '·' '·' '·' '·' '·' '·' '·']
#  ['·' '·' 'O' '·' '·' '·' 'O' '·' '·' '·']
#  ['·' '·' '·' '·' '·' '·' 'O' 'O' '·' '·']
#  ['·' '·' '·' '·' '·' '·' '·' '·' '·' '·']
#  ['·' '·' '·' '·' '·' '·' '·' '·' '·' '·']
#  ['·' '·' '·' '·' '·' '·' '·' 'O' 'O' '·']
#  ['·' '·' '·' '·' '·' 'O' '·' '·' '·' 'O']]
# 9 1
# O
# S
# O
# S
# E
# Barco de  3 de eslora colocado en posicion  [(9, 1), (9, 2), (9, 3)] orientación E
# [(9, 1), (9, 2), (9, 3)]
# [['·' '·' '·' '·' '·' '·' '·' '·' '·' '·']
#  ['O' 'O' '·' '·' '·' '·' '·' '·' '·' '·']
#  ['·' '·' '·' '·' '·' '·' '·' '·' '·' '·']
#  ['·' '·' '·' '·' '·' '·' '·' '·' '·' '·']
#  ['·' '·' 'O' '·' '·' '·' 'O' '·' '·' '·']
#  ['·' '·' '·' '·' '·' '·' 'O' 'O' '·' '·']
#  ['·' '·' '·' '·' '·' '·' '·' '·' '·' '·']
#  ['·' '·' '·' '·' '·' '·' '·' '·' '·' '·']
#  ['·' '·' '·' '·' '·' '·' '·' 'O' 'O' '·']
#  ['·' 'O' 'O' 'O' '·' 'O' '·' '·' '·' 'O']]
# 0 7
# E
# Barco de  3 de eslora colocado en posicion  [(0, 7), (0, 8), (0, 9)] orientación E
# [(0, 7), (0, 8), (0, 9)]
# [['·' '·' '·' '·' '·' '·' '·' 'O' 'O' 'O']
#  ['O' 'O' '·' '·' '·' '·' '·' '·' '·' '·']
#  ['·' '·' '·' '·' '·' '·' '·' '·' '·' '·']
#  ['·' '·' '·' '·' '·' '·' '·' '·' '·' '·']
#  ['·' '·' 'O' '·' '·' '·' 'O' '·' '·' '·']
#  ['·' '·' '·' '·' '·' '·' 'O' 'O' '·' '·']
#  ['·' '·' '·' '·' '·' '·' '·' '·' '·' '·']
#  ['·' '·' '·' '·' '·' '·' '·' '·' '·' '·']
#  ['·' '·' '·' '·' '·' '·' '·' 'O' 'O' '·']
#  ['·' 'O' 'O' 'O' '·' 'O' '·' '·' '·' 'O']]
# 0 9
# O
# 5 3
# S
# Barco de  4 de eslora colocado en posicion  [(5, 3), (6, 3), (7, 3), (8, 3)] orientación S
# [(5, 3), (6, 3), (7, 3), (8, 3)]
# [['·' '·' '·' '·' '·' '·' '·' 'O' 'O' 'O']
#  ['O' 'O' '·' '·' '·' '·' '·' '·' '·' '·']
#  ['·' '·' '·' '·' '·' '·' '·' '·' '·' '·']
#  ['·' '·' '·' '·' '·' '·' '·' '·' '·' '·']
#  ['·' '·' 'O' '·' '·' '·' 'O' '·' '·' '·']
#  ['·' '·' '·' 'O' '·' '·' 'O' 'O' '·' '·']
#  ['·' '·' '·' 'O' '·' '·' '·' '·' '·' '·']
#  ['·' '·' '·' 'O' '·' '·' '·' '·' '·' '·']
#  ['·' '·' '·' 'O' '·' '·' '·' 'O' 'O' '·']
#  ['·' 'O' 'O' 'O' '·' 'O' '·' '·' '·' 'O']]
# [['·' '·' '·' '·' '·' '·' '·' 'O' 'O' 'O']
#  ['O' 'O' '·' '·' '·' '·' '·' '·' '·' '·']
#  ['·' '·' '·' '·' '·' '·' '·' '·' '·' '·']
#  ['·' '·' '·' '·' '·' '·' '·' '·' '·' '·']
#  ['·' '·' 'O' '·' '·' '·' 'O' '·' '·' '·']
#  ['·' '·' '·' 'O' '·' '·' 'O' 'O' '·' '·']
#  ['·' '·' '·' 'O' '·' '·' '·' '·' '·' '·']
#  ['·' '·' '·' 'O' '·' '·' '·' '·' '·' '·']
#  ['·' '·' '·' 'O' '·' '·' '·' 'O' 'O' '·']
#  ['·' 'O' 'O' 'O' '·' 'O' '·' '·' '·' 'O']]

# %%
print(tablero_maq)
# Out:
# [['·' '·' '·' '·' '·' '·' '·' 'O' 'O' 'O']
#  ['O' 'O' '·' '·' '·' '·' '·' '·' '·' '·']
#  ['·' '·' '·' '·' '·' '·' '·' '·' '·' '·']
#  ['·' '·' '·' '·' '·' '·' '·' '·' '·' '·']
#  ['·' '·' 'O' '·' '·' '·' 'O' '·' '·' '·']
#  ['·' '·' '·' 'O' '·' '·' 'O' 'O' '·' '·']
#  ['·' '·' '·' 'O' '·' '·' '·' '·' '·' '·']
#  ['·' '·' '·' 'O' '·' '·' '·' '·' '·' '·']
#  ['·' '·' '·' 'O' '·' '·' '·' 'O' 'O' '·']
#  ['·' 'O' 'O' 'O' '·' 'O' '·' '·' '·' 'O']]

# %%
def ocultar_tablero(tablero):
    tablero[::,::] = '·'
    return tablero

# %%
tablero_maq_oculto = ocultar_tablero(tablero_maq)
print(tablero_maq_oculto)
# Out:
# [['·' '·' '·' '·' '·' '·' '·' '·' '·' '·']
#  ['·' '·' '·' '·' '·' '·' '·' '·' '·' '·']
#  ['·' '·' '·' '·' '·' '·' '·' '·' '·' '·']
#  ['·' '·' '·' '·' '·' '·' '·' '·' '·' '·']
#  ['·' '·' '·' '·' '·' '·' '·' '·' '·' '·']
#  ['·' '·' '·' '·' '·' '·' '·' '·' '·' '·']
#  ['·' '·' '·' '·' '·' '·' '·' '·' '·' '·']
#  ['·' '·' '·' '·' '·' '·' '·' '·' '·' '·']
#  ['·' '·' '·' '·' '·' '·' '·' '·' '·' '·']
#  ['·' '·' '·' '·' '·' '·' '·' '·' '·' '·']]
